# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots() #creating figure with one axes
ax.plot([1,2,3,4],[2,3,4,1])

# %%
fig = plt.figure() #an empty figure with no axes
fig, ax = plt.subplots() # a figure with one axes
fig, axes = plt.subplots(2,2) # a fig with 2 grid of axes

# %%
b = np.matrix([[1.2],[3,4]])
b_asarray =np.asarray(b)

# %%
b_asarray
# Out:
# array([[list([1.2]), list([3, 4])]], dtype=object)

# %%
np.random.seed(19680801) #seed the random number generator
data = {'a': np.arange(50),
        'c': np.random.randint(0,50,50),
        'd': np.random.randn(50)}
data['b'] = data['a']+10*np.random.randn(50)
data['d'] = np.abs(data['d'])*100

fig, ax = plt.subplots(figsize=(5,2.7))
ax.scatter('a','b',c='c',s='d',data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %%
x = np.linspace(0,2,100) # sample data

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,x,label='linear')
ax.plot(x,x**2,label='quadratic')
ax.plot(x,x**3,label='cubic')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title("sample plot")
ax.legend()

# %%
def my_plotter(ax,data1,data2,param_dict):
    out = ax.plot(data1,data2, **param_dict)
    return out

data1,data2,data3,data4 = np.random.randn(4,100)

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(5,2.7))
my_plotter(ax1,data1,data2,{'marker':'x'})
my_plotter(ax2,data1,data2,{'marker':'o'})

# %%
x = np.linspace(0,10,100)
fig,ax = plt.subplots(figsize=(5,2.7))
ax.plot(x,np.sin(x),label='sine')
ax.plot(x,np.cos(x),label='cos')

# %%
x = np.linspace(0,10,100)
fig,ax = plt.subplots(figsize=(5,2.7))
ax.plot(x,np.sin(2*x)+np.sin(4*x)+np.sin(6*x),label='sine even x')
ax.plot(x,np.sin(x)+np.sin(3*x)+np.sin(5*x),label='sine odd x')

# %%
x = np.linspace(0,10,100)
fig,ax = plt.subplots(figsize=(5,2.7))
ax.plot(x,np.cos(x)+np.cos(3*x)+np.cos(5*x),label='sine',ls ='--')

# %%
x = np.linspace(0,10,100)
fig,ax = plt.subplots(figsize=(5,2.7))
ax.plot(x,np.sin(x),label='sine')

#function
def exapansion(y,end):
    n =1
    array = []
    sum = 0
    while(n<=end):
        sum = sum +(((-1)^n+1)*((y)^(2*n-1)))/(np.math.factorial(2*n-1))
        n=n+1
    return sum
z = 1
print(exapansion(z,2))  
ax.plot(x,exapansion(x,3),label='expansion')
# Out:
# -1.3333333333333333
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-51f8cfe39002> in <module>
#      13 z = 1
#      14 print(exapansion(z,2))
# ---> 15 ax.plot(x,exapansion(x,3),label='expansion')
#
# <ipython-input-54-51f8cfe39002> in exapansion(y, end)
#       8     sum = 0
#       9     while(n<=end):
# ---> 10         sum = sum +(((-1)^n+1)*((y)^(2*n-1)))/(np.math.factorial(2*n-1))
#      11         n=n+1
#      12     return sum
#
# TypeError: ufunc 'bitwise_xor' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
